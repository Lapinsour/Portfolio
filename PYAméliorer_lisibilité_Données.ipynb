# %% [markdown]
# Certains tableaux de données peuvent être un peu arides. Voici comment les rendre plus lisibles.

# %%
import pandas as pd
import numpy as np

# %%
#Création du DataFrame initial
df = pd.DataFrame(
{
'Mois':pd.date_range(
start = '01-01-2012',
end = '31-12-2022',
freq = 'MS'
),
'Visites_produits':np.random.randint(
low = 1_000_000,
high = 2_500_000,
size = 132
),
'Exemplaires_vendus':np.random.randint(
low = 300_000,
high = 500_000,
size = 132
),
'Revenus':np.random.randint(
low = 750_000,
high = 1_250_000,
size = 132
)
}
)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3457: UserWarning: Parsing '31-12-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#Création de nouvelles variables 
df['Conversion'] = df['Exemplaires_vendus']/df['Visites_produits']
df['Prix_unitaire'] = df['Revenus']/df['Exemplaires_vendus']

# %%
#Création d'une ligne "TOTAL"

total = df.sum()
total['Mois'] = pd.NaT
total['Prix_unitaire'] = total['Revenus'] / total['Exemplaires_vendus']
total['Conversion'] = total['Exemplaires_vendus'] / total['Visites_produits']
total = total.to_frame().transpose()


#Style de la ligne "TOTAL"
def highlight_total(s):
    r = pd.Series(data = False,index = s.index)
    r['Mois'] = pd.isnull(s.loc['Mois'])

    return ['font-weight: bold' if r.any() else '' for v in r]


#Ajout de la ligne "TOTAL" à notre DataFrame
d = pd.concat([df,total],axis = 0)
d.reset_index(drop = True,inplace = True)
# Out:
# C:\Users\pierr\AppData\Local\Temp\ipykernel_10480\3045820652.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   total = df.sum()

# %%
#Création d'une fonction pour mettre en lumière certaines données
#Ici, les taux de conversion supérieurs à 30%

def highlight_ventes(s, ventes_threshold = 5):
    r = pd.Series(data = False,index = s.index)
    r['Mois'] = s.loc['Conversion'] > ventes_threshold

    return ['background-color: yellow' if r.any() else '' for v in r]

# %%
#FORMATAGE
d.style\
.set_properties(**{'text-align':'center'})\
.apply(highlight_ventes, ventes_threshold = 0.3, axis=1)\
.apply(highlight_total,axis = 1)\
.format(
{
'Mois':'{:%B %Y}',
'Visites_produits':'{:,.0f}',
'Exemplaires_vendus':'{:,.0f}',
'Revenus':'{:,.0f}€',
'Conversion':'{:.2%}',
'Prix_unitaire':'{:,.2f}€'
},
na_rep = 'TOTAL'
)\
.hide_index()\
.set_caption('Données sur les ventes <br> créées par Pierre Garrigues')
# Out:
# C:\Users\pierr\AppData\Local\Temp\ipykernel_10480\1568703445.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis='index')`
#   d.style\
# <style type="text/css">
# #T_ae695_row0_col0, #T_ae695_row0_col1, #T_ae695_row0_col2, #T_ae695_row0_col3, #T_ae695_row0_col4, #T_ae695_row0_col5, #T_ae695_row1_col0, #T_ae695_row1_col1, #T_ae695_row1_col2, #T_ae695_row1_col3, #T_ae695_row1_col4, #T_ae695_row1_col5, #T_ae695_row2_col0, #T_ae695_row2_col1, #T_ae695_row2_col2, #T_ae695_row2_col3, #T_ae695_row2_col4, #T_ae695_row2_col5, #T_ae695_row3_col0, #T_ae695_row3_col1, #T_ae695_row3_col2, #T_ae695_row3_col3, #T_ae695_row3_col4, #T_ae695_row3_col5, #T_ae695_row4_col0, #T_ae695_row4_col1, #T_ae695_row4_col2, #T_ae695_row4_col3, #T_ae695_row4_col4, #T_ae695_row4_col5, #T_ae695_row5_col0, #T_ae695_row5_col1, #T_ae695_row5_col2, #T_ae695_row5_col3, #T_ae695_row5_col4, #T_ae695_row5_col5, #T_ae695_row6_col0, #T_ae695_row6_col1, #T_ae695_row6_col2, #T_ae695_row6_col3, #T_ae695_row6_col4, #T_ae695_row6_col5, #T_ae695_row7_col0, #T_ae695_row7_col1, #T_ae695_row7_col2, #T_ae695_row7_col3, #T_ae695_row7_col4, #T_ae695_row7_col5, #T_ae695_row10_col0, #T_ae695_row10_col1, #T_ae695_row10_col2, #T_ae695_row10_col3, #T_ae695_row10_col4, #T_ae695_row10_col5, #T_ae695_row11_col0, #T_ae695_row11_col1, #T_ae695_row11_col2, #T_ae695_row11_col3, #T_ae695_row11_col4, #T_ae695_row11_col5, #T_ae695_row12_col0, #T_ae695_row12_col1, #T_ae695_row12_col2, #T_ae695_row12_col3, #T_ae695_row12_col4, #T_ae695_row12_col5, #T_ae695_row13_col0, #T_ae695_row13_col1, #T_ae695_row13_col2, #T_ae695_row13_col3, #T_ae695_row13_col4, #T_ae695_row13_col5, #T_ae695_row14_col0, #T_ae695_row14_col1, #T_ae695_row14_col2, #T_ae695_row14_col3, #T_ae695_row14_col4, #T_ae695_row14_col5, #T_ae695_row15_col0, #T_ae695_row15_col1, #T_ae695_row15_col2, #T_ae695_row15_col3, #T_ae695_row15_col4, #T_ae695_row15_col5, #T_ae695_row16_col0, #T_ae695_row16_col1, #T_ae695_row16_col2, #T_ae695_row16_col3, #T_ae695_row16_col4, #T_ae695_row16_col5, #T_ae695_row17_col0, #T_ae695_row17_col1, #T_ae695_row17_col2, #T_ae695_row17_col3, #T_ae695_row17_col4, #T_ae695_row17_col5, #T_ae695_row18_col0, #T_ae695_row18_col1, #T_ae695_row18_col2, #T_ae695_row18_col3, #T_ae695_row18_col4, #T_ae695_row18_col5, #T_ae695_row19_col0, #T_ae695_row19_col1, #T_ae695_row19_col2, #T_ae695_row19_col3, #T_ae695_row19_col4, #T_ae695_row19_col5, #T_ae695_row21_col0, #T_ae695_row21_col1, #T_ae695_row21_col2, #T_ae695_row21_col3, #T_ae695_row21_col4, #T_ae695_row21_col5, #T_ae695_row23_col0, #T_ae695_row23_col1, #T_ae695_row23_col2, #T_ae695_row23_col3, #T_ae695_row23_col4, #T_ae695_row23_col5, #T_ae695_row24_col0, #T_ae695_row24_col1, #T_ae695_row24_col2, #T_ae695_row24_col3, #T_ae695_row24_col4, #T_ae695_row24_col5, #T_ae695_row27_col0, #T_ae695_row27_col1, #T_ae695_row27_col2, #T_ae695_row27_col3, #T_ae695_row27_col4, #T_ae695_row27_col5, #T_ae695_row31_col0, #T_ae695_row31_col1, #T_ae695_row31_col2, #T_ae695_row31_col3, #T_ae695_row31_col4, #T_ae695_row31_col5, #T_ae695_row32_col0, #T_ae695_row32_col1, #T_ae695_row32_col2, #T_ae695_row32_col3, #T_ae695_row32_col4, #T_ae695_row32_col5, #T_ae695_row34_col0, #T_ae695_row34_col1, #T_ae695_row34_col2, #T_ae695_row34_col3, #T_ae695_row34_col4, #T_ae695_row34_col5, #T_ae695_row35_col0, #T_ae695_row35_col1, #T_ae695_row35_col2, #T_ae695_row35_col3, #T_ae695_row35_col4, #T_ae695_row35_col5, #T_ae695_row37_col0, #T_ae695_row37_col1, #T_ae695_row37_col2, #T_ae695_row37_col3, #T_ae695_row37_col4, #T_ae695_row37_col5, #T_ae695_row38_col0, #T_ae695_row38_col1, #T_ae695_row38_col2, #T_ae695_row38_col3, #T_ae695_row38_col4, #T_ae695_row38_col5, #T_ae695_row39_col0, #T_ae695_row39_col1, #T_ae695_row39_col2, #T_ae695_row39_col3, #T_ae695_row39_col4, #T_ae695_row39_col5, #T_ae695_row40_col0, #T_ae695_row40_col1, #T_ae695_row40_col2, #T_ae695_row40_col3, #T_ae695_row40_col4, #T_ae695_row40_col5, #T_ae695_row41_col0, #T_ae695_row41_col1, #T_ae695_row41_col2, #T_ae695_row41_col3, #T_ae695_row41_col4, #T_ae695_row41_col5, #T_ae695_row42_col0, #T_ae695_row42_col1, #T_ae695_row42_col2, #T_ae695_row42_col3, #T_ae695_row42_col4, #T_ae695_row42_col5, #T_ae695_row43_c ...
